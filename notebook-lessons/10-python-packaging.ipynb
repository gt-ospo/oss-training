# %% [markdown]
# # Module 10 - Packaging
#
# ## Please view the listed sections at [intersect training](https://intersect-training.org/packaging/index.html).
#
# The primary purpose of this module is to briefly introduce a generic workflow in preparing Python packages. Focus on the general steps in converting code into packages in addition to methods of deploying documentation.
#
# Read the summary and these sections:
# - `2. Code to Package`
# - `4. Metadata`
# - `6. Publishing package and citation`
# - `8. Documentation with Sphinx`
# - `9. Documentation with MkDocs`.
#
# These will be used in the problem set `PS10 - Packaging`. (If you don't see it in PS_OSPO, don't worry about it!)
#
# <img alt="Intersect Training packaging menu" src="./img/Packaging.png" style="height:600px">
# </img>

# %%
# Iframe for your convenience

from IPython.display import IFrame

IFrame("https://intersect-training.org/packaging/index.html", width=1000, height=800)
# Out:
#         <iframe
#             width="1000"
#             height="800"
#             src="https://intersect-training.org/packaging/index.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
